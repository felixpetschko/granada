# %%
import SCCAF
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import SCCAF
#
# File /scratch/c9881013/.conda_envs/sccaf-env/lib/python3.11/site-packages/SCCAF/__init__.py:32
#      29 import seaborn as sns
#      30 import patsy
# ---> 32 from scanpy import settings as sett
#      33 from scanpy import logging as logg
#      35 import scanpy as sc
#
# File /scratch/c9881013/.conda_envs/sccaf-env/lib/python3.11/site-packages/scanpy/__init__.py:16
#      11     except ModuleNotFoundError:
#      12         raise RuntimeError(
#      13             "scanpy is not correctly installed. Please install it, e.g. with pip."
#      14         )
# ---> 16 from ._utils import check_versions
#      18 check_versions()
#      19 del check_versions
#
# File /scratch/c9881013/.conda_envs/sccaf-env/lib/python3.11/site-packages/scanpy/_utils/__init__.py:21
# ...
